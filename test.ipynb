# %%
import pandas as pd

# %%
ds = pd.read_csv('data/results.csv')

# %%
ds_sample = ds[ds['raceId'] == 18]

# %%
ds_sample
# Out:
#     resultId  raceId  driverId  constructorId number  grid position  \
# 0          1      18         1              1     22     1        1
# 1          2      18         2              2      3     5        2
# 2          3      18         3              3      7     7        3
# 3          4      18         4              4      5    11        4
# 4          5      18         5              1     23     3        5
# 5          6      18         6              3      8    13        6
# 6          7      18         7              5     14    17        7
# 7          8      18         8              6      1    15        8
# 8          9      18         9              2      4     2       \N
# 9         10      18        10              7     12    18       \N
# 10        11      18        11              8     18    19       \N
# 11        12      18        12              4      6    20       \N
# 12        13      18        13              6      2     4       \N
# ...

# %%
# sort rank
ds_sample = ds_sample.sort_values(by='fastestLapTime')

# %%
ds_sample
# Out:
#     resultId  raceId  driverId  constructorId number  grid position  \
# 4          5      18         5              1     23     3        5
# 0          1      18         1              1     22     1        1
# 1          2      18         2              2      3     5        2
# 7          8      18         8              6      1    15        8
# 2          3      18         3              3      7     7        3
# 12        13      18        13              6      2     4       \N
# 3          4      18         4              4      5    11        4
# 21        22      18        22             11     17    10       \N
# 8          9      18         9              2      4     2       \N
# 14        15      18        15              7     11     6       \N
# 13        14      18        14              9      9     8       \N
# 6          7      18         7              5     14    17        7
# 9         10      18        10              7     12    18       \N
# ...
